# %% [markdown]
# <a href="https://colab.research.google.com/github/Sjleerodls/Data_Analysis/blob/main/lab_da/da04_matplotlib_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 필요한 모듈 import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 데이터 셋 준비

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# # `matplotlib.pyplot` 모듈을 사용한 데이터 시각화

# %%
# 1. Figure 객체 생성
fig = plt.figure()  # 변수 할당

# 2. Figure 객체에 Axis 설정 - Subplot을 생성
# axis = fig.add_subplot(1, 1, 1)     # add_subplot(nrows, ncols, index), fig.add_subplot(2, 1, 2), fig.add_subplot(1, 2, 2)
axis = fig.add_subplot(111)     # add_subplot(pos) : '행/열/인덱스' 순서로 만들어진 3자리 정수 삽입

# 3. Axis에 그래프를 그림.
axis.hist(x=tips.total_bill)    # 히스토그램 생성, 연속된 숫자일 때

# 4. 그래프 옵션 설정
axis.set_title('Histogram (total_bill)')
axis.set_xlabel('Total Bill')
axis.set_ylabel('Count')

# 5. 그래프 보여주기.
plt.show()      # 리턴값이 None 이기 때문에 출력되는 텍스트 값이 없음.

# %%
# 1. Figure, Axis 객체 생성
fig, axis = plt.subplots()  # subplot의 파라미터 nrows, ncols의 기본값이 1로 설정

# 2. 그래프 그림
axis.hist(x=tips.tip)

# 3. 옵션 설정
axis.set_title('Histogram(tip)')
axis.set_xlabel('Tip')
axis.set_ylabel('Count')

# 4. 그래프 보여줌.
plt.show()

# %% [markdown]
# 1개의 Figure에 1개의 Subplot(Axes)만 있는 경우에는 matplotlib.pyplot 모듈의 top-level 그래프 함수(plot, scatter, hist, boxplot, ...)만 이용할 수 있음.
#
# top-level 그래프 함수를 사용하면 Figure, Axes 객체를 생성하는 코드를 작성할 필요가 없음.

# %%
# 그래프 그림()
plt.scatter(x=tips.total_bill, y=tips.tip)      # 단순히 하나의 기본적인 그래프만 그릴 때

# 옵션 설정 - plt 모듈의 top-level 함수 이용
plt.title('Scatter plot')
plt.xlabel('Total Bill')
plt.ylabel('Tip')

# 그래프 보여주기
plt.show()

# %%
plt.hist(x=tips.total_bill)
plt.title('Histogram')
plt.show()

# %% [markdown]
# # Box Plot(상자 그림)
#
# 연속형 자료(숫자 타입 데이터)의 기술 통계량(최솟값, 25%, 중위값(중앙값), 75%, 최댓값)과 이상치(outlier)를 시각화.

# %%
tips.total_bill.describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
plt.boxplot(x=tips.total_bill)
plt.title('Box Plot')
plt.ylabel('Total Bill')
plt.grid()  # 보조선 나타내기.
plt.show()

# %%
tips[['total_bill', 'tip']].describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %%
plt.boxplot(x=[tips.total_bill, tips.tip],
            tick_labels=['total bill', 'tip'])      # tick_labels= 는 boxplot일 때만 사용 가능한 것으로 보여짐.
plt.grid()
plt.show()

# %% [markdown]
# 1개의 Figure에 2개의 Subplot(Axes)을 좌/우로 배치. 왼쪽에는 total_bill의 box plot을, 오른쪽에는 tip의 box plot을 시각화.

# %%
# 1. Figure 객체 생성
fig = plt.figure()
# fig2 = plt.figure()

# 2. Figure 객체에 Axis 설정 - Subplot을 생성
axis = fig.add_subplot(121)     # add_subplot(pos) : '행/열/인덱스' 순서로 만들어진 3자리 정수 삽입
axis2 = fig.add_subplot(122)

# 3. Axis에 그래프를 그림.
axis.boxplot(x=tips.total_bill)    # 히스토그램 생성, 연속된 숫자일 때
axis2.boxplot(x=tips.tip)


# 4. 그래프 옵션 설정
axis.set_title('Boxplot (total_bill)')
axis.set_xlabel('Total Bill')
axis.set_ylabel('Count')

axis2.set_title('BoxPlot')
axis2.set_ylabel('Frequency')

# 5. 그래프 보여주기.
plt.show()      # 리턴값이 None 이기 때문에 출력되는 텍스트 값이 없음.

# %%
fig = plt.figure()  # Figure 객체 생성
ax1 = fig.add_subplot(1, 2, 1)  # 첫번째 Axes를 Figure 추가. fig.add_subplot(121)
ax2 = fig.add_subplot(122)      # 두번째 Axes를 추가

ax1.boxplot(x=tips.total_bill, tick_labels=['total bill'])
ax2.boxplot(x=tips.tip, tick_labels=['tip'])

ax1.grid()
ax2.grid()

plt.show()

# %%
fig, axes = plt.subplots(ncols=2)

# print(type(axes))     #> ndarray(배열)
# print(axes)   # axes로 이루어진 배열, Axes 객체 2개를 저장하느 배열

# 배열의 인덱스 활용
axes[0].boxplot(x=tips.total_bill, tick_labels=['total bill'])
axes[1].boxplot(x=tips.tip, tick_labels=['tip'])

axes[0].grid()
axes[1].grid()

plt.show()

# %% [markdown]
# ## 성별 팁의 box plot
#
# * 남성(Male) tip의 기술 통계량 출력
# * 여성(Female) tip의 기술 통계량 출력
# * 성별 tip의 box plot을 1개의 Axes에 시각화

# %%
print("Male describe")
print(tips[tips.sex == 'Male'].tip.describe())
print()
print('Female describe')
print(tips[tips.sex == 'Female'].tip.describe())
# Out:
# Male describe
# count    157.000000
# mean       3.089618
# std        1.489102
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.760000
# max       10.000000
# Name: tip, dtype: float64
#
# Female describe
# count    87.000000
# mean      2.833448
# std       1.159495
# min       1.000000
# 25%       2.000000
# 50%       2.750000
# 75%       3.500000
# max       6.500000
# Name: tip, dtype: float64

# %%
plt.boxplot(x=[tips[tips.sex == 'Male'].tip, tips[tips.sex == 'Female'].tip],
            tick_labels=['Male', 'Female'])
plt.ylabel('Tip')
plt.grid()
plt.show()

# %%
male_tips = tips[tips.sex == 'Male'].tip
male_tips.describe()
# Out:
# count    157.000000
# mean       3.089618
# std        1.489102
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.760000
# max       10.000000
# Name: tip, dtype: float64

# %%
female_tips = tips[tips.sex == 'Female'].tip
female_tips.describe()
# Out:
# count    87.000000
# mean      2.833448
# std       1.159495
# min       1.000000
# 25%       2.000000
# 50%       2.750000
# 75%       3.500000
# max       6.500000
# Name: tip, dtype: float64

# %%
plt.boxplot(x=[male_tips, female_tips], tick_labels=['Male', 'Female'])

plt.grid()
plt.show()

# %% [markdown]
# 시간(Lunch, Dinner)별 tip의 box plot

# %%
tip_dinner = tips[tips.time == 'Dinner'].tip
tip_lunch = tips[tips.time == 'Lunch'].tip

plt.boxplot(x = [tip_dinner, tip_lunch],
            tick_labels=['Dinner', 'Lunch'])

plt.ylabel('tip')
plt.grid()
plt.show()

# %% [markdown]
# 요일별 tip의 box plot

# %%
# Sun, Sat, Thur, Fri

sun = tips[tips.day == 'Sun'].tip
sat = tips[tips.day == 'Sat'].tip
fri = tips[tips.day == 'Fri'].tip
thur = tips[tips.day == 'Thur'].tip

data=[thur, fri, sat, sun]
plt.boxplot(x=data, tick_labels=['thur', 'fri', 'sat', 'sun'])

plt.show()

# %%
# Sun, Sat, Thur, Fri
sun = tips[tips.day == 'Sun'].tip
sat = tips[tips.day == 'Sat'].tip
thur = tips[tips.day == 'Thur'].tip
fri = tips[tips.day == 'Fri'].tip

fig = plt.figure()
ax1 = fig.add_subplot(1, 4, 1)
ax2 = fig.add_subplot(1, 4, 2)
ax3 = fig.add_subplot(1, 4, 3)
ax4 = fig.add_subplot(1, 4, 4)

ax1.boxplot(sun)
ax2.boxplot(sat)
ax3.boxplot(thur)
ax4.boxplot(fri)

plt.show()

# %%
lunch_tips = tips[tips.time == 'Lunch'].tip
lunch_tips.describe()
# Out:
# count    68.000000
# mean      2.728088
# std       1.205345
# min       1.250000
# 25%       2.000000
# 50%       2.250000
# 75%       3.287500
# max       6.700000
# Name: tip, dtype: float64

# %%
dinner_tips = tips[tips.time == 'Dinner'].tip
dinner_tips.describe()
# Out:
# count    176.000000
# mean       3.102670
# std        1.436243
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.687500
# max       10.000000
# Name: tip, dtype: float64

# %%
plt.boxplot(x = [lunch_tips, dinner_tips], tick_labels=['Lunch', 'Dinner'])

plt.grid()
plt.show()

# %%
tips.day.unique()   #> DataFrame에서 값이 등장하는 순서대로 유일한 값들을 리턴.
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips.day.cat.categories     #> data_frame.column.cat.categories: 카테고리 객체
# Out:
# Index(['Thur', 'Fri', 'Sat', 'Sun'], dtype='object')

# %%
# 카테고리 객체는 배열처럼 for-in 반복문에서 사용할 수 있는 iterable 타입
data = []   # 요일별 tip 컬럼들을 저장하기 위한 빈 리스트
for c in tips.day.cat.categories:
    tip_by_day = tips[tips.day == c].tip    # tip 데이터
    data.append(tip_by_day)

plt.boxplot(x = data, tick_labels=tips.day.cat.categories)
plt.show()

# %% [markdown]
# ## Histogram(히스토그램)
#
# 연속형 자료(숫자 타입 데이터)를 구간으로 나눠서 구간 안에 포함된 자료의 개수를 막대로 시각화한 그래프.

# %%
plt.hist(x=tips.total_bill,     # x=히스토그램을 그리기 위한 연속형 자료(변수, 컬럼)
         bins=10,               # bins=막대 개수 또는 구간(배열) / np.arange(0, 70, 10) / [10, 20, 30, 40, 50, 60]
         edgecolor='IndianRed',     # edgecolor=막대 테두리 색깔
         color='White')             # color=막대 내부를 채우는 색깔

plt.xlabel('Total bill')
plt.ylabel('Count')
# plt.yticks([0, 10, 20, 30, 50, 60])
plt.grid()
plt.show()

# %%
# tip의 히스토그램
plt.hist(x=tips.tip, edgecolor='black', color='lightgray')
plt.grid()
plt.xlabel('Tip')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Bar Plot(막대 그래프)
#
# 카테고리(범주) 타입의 변수(컬럼)의 빈도수를 막대로 표현한 그래프.

# %% [markdown]
# ## 세로 막대 그래프(vertical bar plot)

# %%
gender_count = tips.sex.value_counts()
print(type(gender_count))
print(gender_count)
# Out:
# <class 'pandas.core.series.Series'>
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
print(type(gender_count))
# Out:
# <class 'pandas.core.series.Series'>

# %%
gender_count.index
# Out:
# CategoricalIndex(['Male', 'Female'], categories=['Male', 'Female'], ordered=False, dtype='category', name='sex')

# %%
gender_count.values
# Out:
# array([157,  87])

# %%
# plt.figure(figsize=(4, 5))
plt.bar(x=gender_count.index, height=gender_count.values, width=0.4)
plt.grid()
plt.show()

# %% [markdown]
# ## 가로 막대 그래프(horizontal bar plot)

# %%
plt.barh(y=gender_count.index,
         width=gender_count.values,
         height=0.4)

plt.show()

# %% [markdown]
# 테이블의 손님 수(size)의 빈도수를 세로 막대 그래프로 시각화.

# %%
tip_value = tips['size'].value_counts()

plt.bar(x=tip_value.index,
         height=tip_value.values)

plt.show()

# %% [markdown]
# 요일의 빈도수를 가로 막대 그래프로 시각화.

# %%
day_count = tips.day.value_counts()

plt.barh(y=day_count.index,
        width=day_count.values,
        color='green',
        edgecolor='black')

plt.grid()
plt.show()

# %% [markdown]
# * 4개의 Axes(subplot)을 2x2 모양(nrows=2, ncols=2)으로 생성
# * 각 Axes에 성별 빈도수, 흡연여부 빈도수, 요일 빈도수, 시간 빈도수 막대 그래프를 그리세요.

# %%
fig, axis = plt.subplots(nrows=2, ncols=2)

sex_count = tips.sex.value_counts()
smoke_count = tips['smoker'].value_counts()
day_count = tips['day'].value_counts()
time_count = tips.time.value_counts()

axis[0][0] = plt.bar(x=sex_count.index,
               height=sex_count.values)
axis[0][0] = plt.bar(x=smoke_count.index,
                  height=smoke_count.values)
axis[0][0] = plt.bar(x=day_count.index,
                     height=day_count.values)
axis[1][1] = plt.bar(x=time_count.index,
                     height=time_count.values)


plt.show()

# %%
gender_count = tips.sex.value_counts()
smoker_count = tips.smoker.value_counts()
day_count = tips.day.value_counts()
time_count = tips.time.value_counts()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8))
# print(axes) #> 2차원 ndarray

axes[0, 0].bar(x=gender_count.index,
                height=gender_count.values)
axes[0, 0].set_title('Gender')
axes[0, 1].bar(x=smoker_count.index,
               height=smoker_count.values)
axes[0, 1].set_title('Smoker')
axes[1, 0].bar(x=day_count.index,
               height=day_count.values)
axes[1, 0].set_title('Day')
axes[1, 1].bar(x=time_count.index,
               height=time_count.values)
axes[1, 1].set_title('Time')

plt.show()

# %%
titles = [['sex', 'smoker'], ['day', 'time']]       # 2차원 행렬 생성

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(5, 5))  # fig에 2x2의 axes 객체 생성, 사이즈는 figsize로 조절

for i, row in enumerate(titles):
    for j, t in enumerate(row):
        data = tips[t].value_counts()
        axes[i, j].bar(x=data.index,
                       height=data.values)
        axes[i, j].set_title(t)

plt.show()

# %% [markdown]
# # Scatter Plot(산점도)
#
# * 두 변수 (컬럼) 간의 상관 관계를 알고 싶을 때 사용.
# * `y ~ x` 관계 시각화.
#     * `y` : 관심 변수, 종속 변수.
#     * `x` : 독립 변수.

# %%
# tip ~ total_bill 상관 관계
plt.scatter(x=tips.total_bill, y=tips.tip, # x, y: x축, y축에 사용할 변수(컬럼)
            alpha=0.3,              # alpha : 투명도(0=투명, 1=불투명)
            s=30,                   # s : size. 마커(점)의 크기.
            c='IndianRed',          # c: color. 마커(점)의 색깔.
            marker='*')             # marker : 마커(점)의 모양 (o, s, v, ^, *, +, ...).
plt.xlabel('Total bill')
plt.ylabel('Tip')
plt.grid()
plt.show()

# %% [markdown]
# * tip ~ total_bill 상관 관계를 산점도로 시각화
# * 성별에 따라서 마커의 색깔을 다르게 표시.

# %%
male_df = tips[tips.sex == 'Male']
female_df = tips[tips.sex == 'Female']

plt.scatter(x=male_df.total_bill, y=male_df.tip, alpha=0.3, label='Male', c='DodgerBlue')
plt.scatter(x=female_df.total_bill, y=female_df.tip, alpha=0.3, label='Female', c='IndianRed')

plt.xlabel('Total bill')
plt.ylabel('Tip')
plt.legend()        # 범례 표시 - 각각의 산점도의 레이블을 표시.

plt.show()

# %% [markdown]
# * tip ~ total_bill 산점도
# * 성별에 따라서 마커의 색깔을 다르게 지정.
# * 흡연 여부에 따라서 마커의 모양을 다르게 지정.

# %%
male_y = tips[(tips.sex == 'Male') & (tips.smoker == 'Yes')]
male_n = tips[(tips.sex == 'Male') & (tips.smoker == 'No')]
female_y = tips[(tips.sex == 'Female') & (tips.smoker == 'Yes')]
female_n = tips[(tips.sex == 'Female') & (tips.smoker == 'No')]

plt.scatter(x=male_y.total_bill, y=male_y.tip, label='Male, Smoker', c='green', marker = '*')
plt.scatter(x=male_n.total_bill, y=male_n.tip, label='Male, No Smoker', c='blue')
plt.scatter(x=female_y.total_bill, y=female_y.tip, label='Female, Smoker', c='purple', marker ='*')
plt.scatter(x=female_n.total_bill, y=female_n.tip, label='Female, No Smoker', c='red')


plt.xlabel('Total bill')
plt.ylabel('Tip')
plt.legend()
plt.show()

# %%
male_smoker = tips[(tips.sex == 'Male') & (tips.smoker == 'Yes')]
male_nonsmoker = tips[(tips.sex == 'Male') & (tips.smoker == 'No')]
female_smoker = tips[(tips.sex == 'Female') & (tips.smoker == 'Yes')]
female_nonsmoker = tips[(tips.sex == 'Female') & (tips.smoker == 'No')]

plt.scatter(x = male_smoker.total_bill, y = male_smoker.tip,
            alpha = 0.4,
            c='blue',
            marker='o',
            label='Male-Smoker')
plt.scatter(x = male_nonsmoker.total_bill, y = male_nonsmoker.tip,
            alpha = 0.4,
            c='blue',
            marker='^',
            label='Male-NonSmoker')
plt.scatter(x = female_smoker.total_bill, y = female_smoker.tip,
            alpha=0.4,
            c='red',
            marker='o',
            label='Female-Smoker')
plt.scatter(x = female_nonsmoker.total_bill, y = female_nonsmoker.tip,
            alpha=0.4,
            c='red',
            marker='^',
            label='Female-NonSmoker')

plt.legend()        # 각각의 scatter 함수의 label을 범례 표시.
plt.xlabel('Total bill')
plt.ylabel('Tip')
plt.grid()

plt.show()

# %%
tips[(tips.sex == 'Male') & (tips.smoker == 'Yes')].head()
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 56       38.01  3.00  Male    Yes  Sat  Dinner     4
# 58       11.24  1.76  Male    Yes  Sat  Dinner     2
# 60       20.29  3.21  Male    Yes  Sat  Dinner     2
# 61       13.81  2.00  Male    Yes  Sat  Dinner     2
# 62       11.02  1.98  Male    Yes  Sat  Dinner     2

# %%
gender = tips.sex.cat.categories   # tips.sex.unique()
smoker = tips.smoker.cat.categories     # 여기서 .cat.categories는 dtype이 'category일' 때만 사용 가능함.
colors = ['DodgerBlue', 'IndianRed']    # 성별에 따라서 다르게 표시할 마커 색상 이름
markers = ['s', '^']        # 흡연 여부에 따라서 다르게 표시할 마커의 모양

for g, c in zip(gender, colors):
    for s, m in zip (smoker, markers):
        subset_df = tips[(tips.sex == g) & (tips.smoker == s)]  # tips[(tips.sex == 'Male') & (tips.smoker == 'Yes')] 의 결과와 동일함.
        plt.scatter(x=subset_df.total_bill, y=subset_df.tip,
                    alpha=0.4, c=c, marker=m,
                    label=f'{g} Smoker-{s}')

plt.legend()
plt.xlabel('Total bill')
plt.ylabel('Tip')
plt.grid()

plt.show()

# %% [markdown]
# * 1개의 Figure에 상/하 2개의 Axes를 생성
# * 위쪽 Axes에 total_bill 히스토그램을 작성
# * 아래쪽 Axes에 tip ~ total_bill 산점도를 작성

# %%
fig, ax = plt.subplots(nrows=2)


ax[0].hist(x=tips.total_bill, edgecolor='black', color='green')
ax[1].scatter(x=tips.total_bill, y=tips.tip, s=10, c='purple', marker='^', alpha=0.3)

ax[0].grid()
ax[1].grid()

ax[0].set_title('Histogram')
ax[0].set_xlabel('Bill total')
ax[0].set_ylabel('Tip')

plt.xlabel('Bill total')
plt.ylabel('Tip')
plt.title('Bill Total')
plt.show()

# %% [markdown]
# # Line plot(선 그래프)
#
# 주로 시계열 데이터(주식, 부동산, 지지율, 원자재 가격, 미세먼지 농도, ...)를 시각화.

# %%
# 선 그래프를 그리기 위한 가상 데이터
np.random.seed(1)
df = pd.DataFrame(data={
    'day' : np.arange(1, 11),
    'price' : np.random.rand(10)
})
df
# Out:
#    day     price
# 0    1  0.417022
# 1    2  0.720324
# 2    3  0.000114
# 3    4  0.302333
# 4    5  0.146756
# 5    6  0.092339
# 6    7  0.186260
# 7    8  0.345561
# 8    9  0.396767
# 9   10  0.538817

# %%
# plt.plot(x 좌표로 사용할 변수, y 좌표로 사용할 변수, 포맷 문자열)
# 포맷 문자열 : color(선과 마커의 색상), marker(마커 모양), linestyle(선 스타일/모양) 정보를 문자열로 만듦.
#   color : r(red), g(green), b(blue), k(black), y(yellow), ...
#   marker : o, s, ^, v, *, +
#   linestyle : -(직선, solid line), --(dashed line), :(점선, dotted line), ...
plt.plot(df.day, df.price, 'bo-')

plt.xlabel('day')
plt.ylabel('price')
plt.grid()

plt.show()

# %%
plt.plot(df.day, df.price,
         color='IndianRed', linestyle='dotted', marker='v')

plt.grid()
plt.xlabel('day')
plt.ylabel('price')

plt.show()

# %% [markdown]
# # 연습문제 1.
#
# 아래의 데이터프레임에서 samsung, hynix, nvidia 데이터를 선 그래프로 그리세요.
# * 선 그래프 3개가 함께 표현
# * 각각의 데이터는 다른 색깔, 마커, 선 스타일로 표현
# * 범례 표시

# %%
np.random.seed(1)
df = pd.DataFrame({'samsung' : np.random.rand(10),
                   'hynix' : np.random.rand(10),
                   'nvidia' : np.random.rand(10)
                   })
df

plt.plot(df.samsung, c='blue', marker='v', linestyle=':', label='Samsung')
plt.plot(df.hynix, c='red', marker='*', linestyle='--', label='Hynix')
plt.plot(df.nvidia, c='green', marker='s', linestyle='-', label='Nvidia')

plt.legend()
plt.show()

# %%
plt.plot(df.samsung, 'bo-', label='samsung')
plt.plot(df.hynix, 'rs:', label='hynix')
plt.plot(df.nvidia, 'gv--', label='nvidia')

plt.legend()

plt.show()

# %% [markdown]
# # 연습문제 2.
#
# iris 데이터셋 시각화.
# * seaborn 패키지의 iris 예제 데이터셋 로드
# * DataFrame 확인 (`head, info, describe, value_counts` 등)
# * petal_width ~ petal_length 산점도
#     * species 별로 마커의 색깔을 다르게 표현

# %% [markdown]
# ![iris.png](data:image/png;base64,...)

# %%
df = sns.load_dataset('iris')

head = df.head()
print(head)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
info = df.info()
print(info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
# 연속형 변수들의 기술 통계량
describe = df.describe()
print(describe)
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# 카테고리 타입 빈도수
value_count = df.species.value_counts()
print(value_count)
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.species.unique()     # setosa, versicolor, virginica
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# * petal_width ~ petal_length 산점도
    #* species 별로 마커의 색깔을 다르게 표현
se = df[df.species == 'setosa']
ve = df[df.species == 'versicolor']
vi = df[df.species == 'virginica']


plt.scatter(x=se.petal_length, y=se.petal_width, c='blue', marker='s', label='setosa', alpha=0.5)
plt.scatter(x=ve.petal_length, y=ve.petal_width, c='green', marker='*', label='versicolor', alpha=0.5)
plt.scatter(x=vi.petal_length, y=vi.petal_width, c='black', marker='v', label='virginica', alpha=0.5)

plt.xlabel('petal_length(cm)')
plt.ylabel('petal_width(cm)')
plt.legend()
plt.grid()

plt.show()

# %%
species = df.species.unique()
for s in species:
    subset_df = df[df.species == s]
    plt.scatter(x=subset_df.petal_length, y=subset_df.petal_width, label=s, alpha=0.5)

plt.legend()
plt.xlabel('petal length(cm)')
plt.ylabel('petal width(cm)')
plt.grid()

plt.show()

# %%
# boxplot으로 iris 그려보기

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)

ax[0][0].boxplot(x=df['petal_length'], tick_labels=['petal_length'])
ax[0][1].boxplot(x=df['petal_width'], tick_labels=['petal_width'])
ax[1][0].boxplot(x=df['sepal_length'], tick_labels=['sepal_length'])
ax[1][1].boxplot(x=df['sepal_width'], tick_labels=['sepal_width'])

plt.show()

# %%
header_list = list(df.columns)
header_list.pop()

fig, ax = plt.subplots(nrows=2, ncols=2)

for i in range(2):          # 행 반복
    for j in range(2):      # 열 반복
        index = i * 2 + j
        ax[i,j].boxplot(x=df[header_list[index]], tick_labels=[header_list[index]])
        # ax[i][j].boxplot(x=df[header_list[index]], tick_labels=[header_list[index]])

plt.show()
